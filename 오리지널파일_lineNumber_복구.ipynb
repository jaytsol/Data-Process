# %%
import csv
import pandas as pd
from tqdm.notebook import tnrange

# %%
input1_repo = '/Users/jaytsol/Desktop/Type23 (2)/오리지널/절반/'
input2_repo = '/Users/jaytsol/Desktop/Type23 (2)/오리지널/절반/'

input1_filename = 'origin_type2_input_1_0(맨처음한것).csv'
input2_filename = 'origin_type2_input_1_1(맨처음 한것에서 나눈것).csv'

output_repo = '/Users/jaytsol/Desktop/Type23 (2)/오리지널/1/'
output_filename = '1.csv'

# %%
COLUMNS = ['lineNumber', 'originalText']
org1 = pd.read_csv(input1_repo+input1_filename)
org1 = org1[['lineNumber', 'originalText']]
org2 = pd.read_csv(input2_repo+input2_filename)
org2 = org2[['lineNumber', 'originalText']]

# %%
org = pd.concat([org1, org2])

# %%
org
# Out:
#        lineNumber                                       originalText
# 0               1  <<<직전의 재판<=원심>판결 이유에>>> 의하면, <<<직전의 재판<=원심>은 이...
# 1               2  비록 양 발명의 구성에 <<<서로 다름<=상이>점이 있어도>>> 그 기술분야에서 <...
# 2               3  [2] 등록의장의 대상물품인 "스위치"가 독립거래의 대상성 및 <<<연결되는 데 문...
# 3               4  ③ 이 사건 프로젝터에 사용된 LCD는 ***** 컴퓨터나 그 <<<연결되는 데 문...
# 4               5  구 의장법 제2조 제1호에서 말하는 "물품"이란 독립성이 있는 구체적인 유체동산을 ...
# ...           ...                                                ...
# 18532       38344  <<<범죄와 형벌에 관한 법률<=형법> 제307조>>> 제2항의 ‘허위사실 <<<지...
# 18533       38345  [2] 출발하려는 승용차 보닛 위에 올라타 출발을 막기까지 하는 사람을 보닛 위에 ...
# 18534       38346  [3] 유흥업소의 업주로서는 다른 <<<사적이지 않음<=공적> 증명력>>> 있는 증...
# 18535       38348  [1] 사기죄의 주관적 구성요건인 편취의 범의는 <<<형사소송에서 검사에의해 기소당...
# 18536       38350  [2] 살인죄의 범의는 자기의 행위로 인하여 피해자가 사망할 수도 있다는 사실을 인...
#
# [38451 rows x 2 columns]

# %%
org = org.sort_values(by=['lineNumber'])

# %%
org
# Out:
#        lineNumber                                       originalText
# 0               1  <<<직전의 재판<=원심>판결 이유에>>> 의하면, <<<직전의 재판<=원심>은 이...
# 1               2  비록 양 발명의 구성에 <<<서로 다름<=상이>점이 있어도>>> 그 기술분야에서 <...
# 2               3  [2] 등록의장의 대상물품인 "스위치"가 독립거래의 대상성 및 <<<연결되는 데 문...
# 3               4  ③ 이 사건 프로젝터에 사용된 LCD는 ***** 컴퓨터나 그 <<<연결되는 데 문...
# 4               5  구 의장법 제2조 제1호에서 말하는 "물품"이란 독립성이 있는 구체적인 유체동산을 ...
# ...           ...                                                ...
# 19909       38447  [3] <<<특정 재산에 대한 처분 제한 <=압류>재산의 관공서가 하는 강제경매<=...
# 19910       38448  가. ***의 <<<직무나 임무에 힘씀<=복무>기간은 국방의무의>>> 본질적 내용에...
# 19911       38449  <<<직전의 재판<=원심>은, 검사가 형사재판을 신청하는 일<=공소>외>>> 4 주...
# 19912       38450  (가) <<<민사소송을 일으킨 사람<=원고>는 민사소송에서 소송을 당한 사람<=피고...
# 19913       38451  [2] 지방공사인 의료원이 약제과장으로 근무하던 근로자에 대한 <<<어떤 직무를 담...
#
# [38451 rows x 2 columns]

# %%
org.to_csv(output_repo+output_filename, encoding='utf-8-sig', index=False)
