# %%
# type3_output 예시 json 데이터 생성 (행정처분)

# %%
import json

# %%
def zerolists(num):
    listofzeros = [0] * num
    return listofzeros

# %%
difficult_word = {"행정처분":[],
                 "조세회피":[],}
difficult_word["행정처분"] = zerolists(2)
difficult_word["조세회피"] = zerolists(2)

# %%
difficult_word["행정처분"][0] = {"origin":"[1] ^행정청이 구체적인 사실에 관한 집행을 다툴^ ^소송의 목적은^ 개별·구체적 사정을 고려하여 판단하여야 한다",
                         "trans":"[1] ^행정청이 구체적인 사실에 관한 집행을 다툴^ ^소송의 목적은^ 개별·구체적 사정을 고려하여 판단하여야 한다.",
                         "keyword":["행정청이 구체적인 사실에 관한 집행을 다툴", "소송의 목적은",],
                         "keywordOccurence":
                             [
                                {"start": 4, "end": 26}, 
                                {"start": 28, "end": 37},
                             ],
#                              "number":0
                            }
difficult_word["행정처분"][1] = {"origin":"^행정청이 구체적인 사실에 관한 집행의 무효확인^ 또는 취소를 구하는 소가 ^소송을 제기할 당시에는^ ^소송의 목적이 있어^ 적법하였더라도, 소송 계속 중 처분청이 다툼의 대상이 되는 ^행정청이 구체적인 사실에 관한 집행을 직권으로^ 취소하면 그 처분은 효력을 상실하여 더 이상 존재하지 않는 것이므로, 존재하지 않는 처분을 대상으로 한 ^행정청의 위법한 처분 등을 취소 또는 변경하는 소송은 원칙적으로^ ^소송의 목적이 소멸하여^ 부적법하다고 보아야 한다.",
                         "trans":"^행정청이 구체적인 사실에 관한 집행의 무효확인^ 또는 취소를 구하는 소가 ^소송을 제기할 당시에는^ ^소송의 목적이 있어^ 적법하였더라도, 소송 계속 중 처분청이 다툼의 대상이 되는 ^행정청이 구체적인 사실에 관한 집행을 직권으로^ 취소하면 그 처분은 효력을 상실하여 더 이상 존재하지 않는 것이므로, 존재하지 않는 처분을 대상으로 한 ^행정청의 위법한 처분 등을 취소 또는 변경하는 소송은 원칙적으로^ ^소송의 목적이 소멸하여^ 부적법하다고 보아야 한다.",
                         "keyword":[ 

                            "행정청이 구체적인 사실에 관한 집행의 무효확인", 

                            "소송을 제기할 당시에는", 

                            "소송의 목적이 있어", 

                            "행정청이 구체적인 사실에 관한 집행을 직권으로", 

                            "행정청의 위법한 처분 등을 취소 또는 변경하는 소송은 원칙적으로", 

                            "소송의 목적이 소멸하여", 

                            ],
                         "keywordOccurence":
                             [ 

                                {'start': 0, 'end': 25}, 

                                {'start': 40, 'end': 50}, 

                                {'start': 51, 'end': 61}, 

                                {'start': 95, 'end': 120}, 

                                {'start': 179, 'end': 214}, 

                                {'start': 215, 'end': 227}, 

                            ],
#                          "number":1
                        }

# %%
difficult_word["조세회피"][0] = {"origin":"^재산이나 영토, 권리 따위가 특정 주체에 붙음명의자는 이를^ 지배·관리할 능력이 없고 명의자에 대한 지배권 등을 통하여 실질적으로 이를 지배·관리하는 사람이 따로 있으며 그와 같은 명의와 실질의 괴리가 ^비정상적인 과정을 통해 조세를 피하는 것 목적에서^ 비롯된 경우에는、 그 재산에 관한 소득은 재산을 실질적으로 지배·관리하는 사람에게 귀속된 것으로 보아 그를 납세의무자로 보아 과세하여야 한다.",
                             "trans":"^재산이나 영토, 권리 따위가 특정 주체에 붙은 명의자는 이를^ 지배·관리할 능력이 없고 명의자에 대한 지배권 등을 통하여 실질적으로 이를 지배·관리하는 사람이 따로 있으며 그와 같은 명의와 실질의 괴리가 ^비정상적인 과정을 통해 조세를 피하는 것의 목적에서^ 비롯된 경우에는、 그 재산에 관한 소득은 재산을 실질적으로 지배·관리하는 사람에게 귀속된 것으로 보아 그를 납세의무자로 보아 과세하여야 한다.",
                             "keyword":[
                                    "재산이나 영토, 권리 따위가 특정 주체에 붙음명의자는 이를", 
                                    "비정상적인 과정을 통해 조세를 피하는 것 목적에서", 
                                ],
                             "keywordOccurence":[ 
                                    {'start': 3, 'end': 35}, 
                                    {'start': 115, 'end': 142}, 
                                ],
#                              "number":0
                        }

# %%
difficult_word["조세회피"][1] = {"origin":"[1] ^재산의 재산이나 영토, 권리 따위가 특정 주체에 붙음 명의자가^ 지배·관리 능력이 없고、 명의자에 대한 지배권 등을 통하여 실질적으로 지배·관리하는 자가 따로 있으며、 명의와 실질의 괴리가 ^비정상적인 과정을 통해 조세를 피하는 것 목적에서^ 비롯된 경우、 재산에 관한 소득의 납세의무자(=재산의 실질적 지배·관리자) 및 이 원칙이 ^소득 및 자본에 대한 국제적 이중과세를 방지하기 위한 약속의^ 해석과 적용에서도 그대로 적용되는지 여부(원칙적 적극)",
                         "trans":"[1] ^재산의 재산이나 영토, 권리 따위가 특정 주체에 붙은 명의자가^ 지배·관리 능력이 없고、 명의자에 대한 지배권 등을 통하여 실질적으로 지배·관리하는 자가 따로 있으며、 명의와 실질의 괴리가 ^비정상적인 과정을 통해 조세를 피하는 것의 목적에서^ 비롯된 경우、 재산에 관한 소득의 납세의무자(=재산의 실질적 지배·관리자) 및 이 원칙이 ^소득 및 자본에 대한 국제적 이중과세를 방지하기 위한 약속의^ 해석과 적용에서도 그대로 적용되는지 여부(원칙적 적극)",
                         "keyword":
                            [ 
                                "재산이나 영토, 권리 따위가 특정 주체에 붙음 명의자가", 
                                "비정상적인 과정을 통해 조세를 피하는 것 목적에서", 
                                "소득 및 자본에 대한 국제적 이중과세를 방지하기 위한 약속의", 
                            ],
                         "keywordOccurence":
                            [ 
                                {'start': 8, 'end': 38}, 
                                {'start': 109, 'end': 136}, 
                                {'start': 187, 'end': 220}, 
                            ],
#                           "number":1
                        }

# %%
difficult_word
# Out:
# {'행정처분': [{'origin': '[1] ^행정청이 구체적인 사실에 관한 집행을 다툴^ ^소송의 목적은^ 개별·구체적 사정을 고려하여 판단하여야 한다',
#    'trans': '[1] ^행정청이 구체적인 사실에 관한 집행을 다툴^ ^소송의 목적은^ 개별·구체적 사정을 고려하여 판단하여야 한다.',
#    'keyword': ['행정청이 구체적인 사실에 관한 집행을 다툴', '소송의 목적은'],
#    'keywordOccurence': [{'start': 4, 'end': 26}, {'start': 28, 'end': 37}]},
#   {'origin': '^행정청이 구체적인 사실에 관한 집행의 무효확인^ 또는 취소를 구하는 소가 ^소송을 제기할 당시에는^ ^소송의 목적이 있어^ 적법하였더라도, 소송 계속 중 처분청이 다툼의 대상이 되는 ^행정청이 구체적인 사실에 관한 집행을 직권으로^ 취소하면 그 처분은 효력을 상실하여 더 이상 존재하지 않는 것이므로, 존재하지 않는 처분을 대상으로 한 ^행정청의 위법한 처분 등을 취소 또는 변경하는 소송은 원칙적으로^ ^소송의 목적이 소멸하여^ 부적법하다고 보아야 한다.',
#    'trans': '^행정청이 구체적인 사실에 관한 집행의 무효확인^ 또는 취소를 구하는 소가 ^소송을 제기할 당시에는^ ^소송의 목적이 있어^ 적법하였더라도, 소송 계속 중 처분청이 다툼의 대상이 되는 ^행정청이 구체적인 사실에 관한 집행을 직권으로^ 취소하면 그 처분은 효력을 상실하여 더 이상 존재하지 않는 것이므로, 존재하지 않는 처분을 대상으로 한 ^행정청의 위법한 처분 등을 취소 또는 변경하는 소송은 원칙적으로^ ^소송의 목적이 소멸하여^ 부적법하다고 보아야 한다.',
#    'keyword': ['행정청이 구체적인 사실에 관한 집행의 무효확인',
#     '소송을 제기할 당시에는',
#     '소송의 목적이 있어',
#     '행정청이 구체적인 사실에 관한 집행을 직권으로',
# ...

# %%
with open('C:/Users/jayts/OneDrive/바탕 화면/Tictag/json/KAS/type3_output.json', 'w', encoding='UTF-8') as file:
    file.write(json.dumps(difficult_word, indent=4, ensure_ascii=False))
