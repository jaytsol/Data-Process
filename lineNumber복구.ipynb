# %%
import csv
import pandas as pd
from tqdm.notebook import tnrange

# %%
org = pd.read_csv('/Users/jaytsol/Desktop/Type23 (2)/오리지널/total_original/save_lineNumber_copy.csv')

# %%
org
# Out:
#       word                                                org  \
# 0       호환  원심판결 이유에 의하면, 원심은 이 사건 행위가 공정거래법 제3조의2 제1항 제3호...
# 1       호환  비록 양 발명의 구성에 상이점이 있어도 그 기술분야에서 통상의 지식을 가진 자가 보...
# 2       호환  [2] 등록의장의 대상물품인 "스위치"가 독립거래의 대상성 및 호환성이 있어 의장법...
# 3       호환  ③ 이 사건 프로젝터에 사용된 LCD는 ***** 컴퓨터나 그 호환컴퓨터에 대표적으...
# 4       호환  구 의장법 제2조 제1호에서 말하는 "물품"이란 독립성이 있는 구체적인 유체동산을 ...
# ...    ...                                                ...
# 75995   종용  1. 기록에 비추어 피고가 시외버스운송사업에 관한 권한을 자동차운송사업법 제62조 ...
# 75996   종용  고소인과 피고인이 같이 거주하던 아파트의 열쇠를 넘겨받고 아울러 피고인 명의로 등기...
# 75997   종용  원심은 거시증거를 종합하여 ****.**.**원고 회사의 무역부장인 소외 ***, ...
# 75998   종용  원고는 자신이 순환명령휴직 대상자에 선정될 것을 예상하고 그와 같은 경우 휴직기간 ...
# 75999   종용  원심판결 이유에 의하면 원심은, 판시와 같은 사실을 인정한 후 그와 같이 인정되는 ...
#
#                                                   tagged
# 0      <<<직전의 재판<=원심>판결 이유에>>> 의하면, <<<직전의 재판<=원심>은 이...
# 1      비록 양 발명의 구성에 <<<서로 다름<=상이>점이 있어도>>> 그 기술분야에서 <...
# ...

# %%
lineNumber = range(1, 76001)
lineNumber = list(lineNumber)

# %%
result = pd.DataFrame(zip(list(lineNumber), list(org['word']), list(org['org']), list(org['tagged'])), columns=['lineNumber', 'word', 'org', 'tagged'])

# %%
result
# Out:
#        lineNumber word                                                org  \
# 0               1   호환  원심판결 이유에 의하면, 원심은 이 사건 행위가 공정거래법 제3조의2 제1항 제3호...
# 1               2   호환  비록 양 발명의 구성에 상이점이 있어도 그 기술분야에서 통상의 지식을 가진 자가 보...
# 2               3   호환  [2] 등록의장의 대상물품인 "스위치"가 독립거래의 대상성 및 호환성이 있어 의장법...
# 3               4   호환  ③ 이 사건 프로젝터에 사용된 LCD는 ***** 컴퓨터나 그 호환컴퓨터에 대표적으...
# 4               5   호환  구 의장법 제2조 제1호에서 말하는 "물품"이란 독립성이 있는 구체적인 유체동산을 ...
# ...           ...  ...                                                ...
# 75995       75996   종용  1. 기록에 비추어 피고가 시외버스운송사업에 관한 권한을 자동차운송사업법 제62조 ...
# 75996       75997   종용  고소인과 피고인이 같이 거주하던 아파트의 열쇠를 넘겨받고 아울러 피고인 명의로 등기...
# 75997       75998   종용  원심은 거시증거를 종합하여 ****.**.**원고 회사의 무역부장인 소외 ***, ...
# 75998       75999   종용  원고는 자신이 순환명령휴직 대상자에 선정될 것을 예상하고 그와 같은 경우 휴직기간 ...
# 75999       76000   종용  원심판결 이유에 의하면 원심은, 판시와 같은 사실을 인정한 후 그와 같이 인정되는 ...
#
#                                                   tagged
# ...

# %%
result.to_csv('/Users/jaytsol/Desktop/Type23 (2)/누적/accum_concat/법률어휘 살리기 최종/total_with_lineNumber.csv', index=False, encoding='utf-8-sig')
